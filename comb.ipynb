# %%
path = "형용사.csv"

# %%
import numpy as np
import pandas as pd

list_of_list = pd.read_csv(path, header=0).values.tolist()

# %%
flattened = [val for sublist in list_of_list for val in sublist if str(val)!='nan']

# %%
np.unique(flattened)
# Out:
# array(['감동받은', '감사하는', '걱정되는', '겁먹은', '겁에 질린', '게으른', '격노한', '격렬한',
#        '견딜 수 있는', '결연한', '경솔한', '경쟁적인', '고통스러운', '공손한', '과장된', '관대한',
#        '관련 없는', '관심 있는', '괴로운', '긍정적인', '기분 상한', '기분 좋은', '기쁜', '긴장한',
#        '깜짝 놀란', '꺾인', '낙관적인', '낙담한', '내키지 않는', '냉담한', '넌더리 난', '놀라운',
#        '뉘우치는', '단호한', '당황스러운', '당황한', '대단한', '동정적인', '마음 넓은', '만족스러운',
#        '멍청한', '명랑한', '명석한', '몰래', '무관심한', '무력한', '무례한', '무모한', '무서운',
#        '무심한', '민감한', '믿기 어려운', '믿을 수 있는', '바보 같은', '배짱 있는', '부러워하는',
#        '부정적인', '부주의한', '불편한', '비관적인', '비판적인', '비현실적인', '사려 깊은', '성가신',
#        '성공적인', '수상쩍은', '수줍어하는', '수치스러운', '순진한', '시기하는', '신난', '신랄한',
#        '신비스러운', '실망한', '싫증난', '심각한', '안도하는', '안심하는', '야망 있는', '어두운',
#        '엄격한', '열광적인', '열렬한', '열성적인', '염려하는', '예민한', '예의 바른', '외로운', '용감한',
#        '우스꽝스러운', '우울한', '유망한', '유머러스한', '유쾌한', '은밀히', '의심하는', '이기적인',
#        '인정 있는', '일치하는', '자랑스러운', '자랑하는', '자신하는', '자포자기하는', '잠재력 있는',
# ...

# %%
from itertools import product 


noun=['aa', 'bb', 'cc']
number=[1,2,3]

items = [flattened, noun, number] 

list(product(*items))
# Out:
# [('순진한', 'aa', 1),
#  ('순진한', 'aa', 2),
#  ('순진한', 'aa', 3),
#  ('순진한', 'bb', 1),
#  ('순진한', 'bb', 2),
#  ('순진한', 'bb', 3),
#  ('순진한', 'cc', 1),
#  ('순진한', 'cc', 2),
#  ('순진한', 'cc', 3),
#  ('기분 좋은', 'aa', 1),
#  ('기분 좋은', 'aa', 2),
#  ('기분 좋은', 'aa', 3),
#  ('기분 좋은', 'bb', 1),
#  ('기분 좋은', 'bb', 2),
#  ('기분 좋은', 'bb', 3),
#  ('기분 좋은', 'cc', 1),
#  ('기분 좋은', 'cc', 2),
#  ('기분 좋은', 'cc', 3),
#  ('일치하는', 'aa', 1),
#  ('일치하는', 'aa', 2),
#  ('일치하는', 'aa', 3),
#  ('일치하는', 'bb', 1),
#  ('일치하는', 'bb', 2),
#  ('일치하는', 'bb', 3),
#  ('일치하는', 'cc', 1),
#  ('일치하는', 'cc', 2),
#  ('일치하는', 'cc', 3),
#  ('감동받은', 'aa', 1),
#  ('감동받은', 'aa', 2),
#  ('감동받은', 'aa', 3),
#  ('감동받은', 'bb', 1),
#  ('감동받은', 'bb', 2),
#  ('감동받은', 'bb', 3),
#  ('감동받은', 'cc', 1),
#  ('감동받은', 'cc', 2),
#  ('감동받은', 'cc', 3),
#  ('놀라운', 'aa', 1),
#  ('놀라운', 'aa', 2),
#  ('놀라운', 'aa', 3),
#  ('놀라운', 'bb', 1),
#  ('놀라운', 'bb', 2),
#  ('놀라운', 'bb', 3),
#  ('놀라운', 'cc', 1),
#  ('놀라운', 'cc', 2),
#  ('놀라운', 'cc', 3),
# ...
